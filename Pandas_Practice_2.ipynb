# %% [markdown]
# <a href="https://colab.research.google.com/github/chandrakant1212/Descriptive-Statistivs-and-EDA/blob/main/Pandas_Practice_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Instructions for Pandas Practice
# ---
# Welcome to the Pandas Practice! In this exercise, you will work with the Rick and Morty dataset to practice your data manipulation and analysis skills using Pandas. Please follow the instructions below carefully:
#
# 1. **Understand the Dataset**: The dataset used in this Practice is related to the Rick and Morty TV show. Familiarize yourself with the dataset's structure and content before starting.
#
# 2. **Read Each Question Thoroughly**: Each question in this Practice is designed to test different Pandas functionalities. Make sure you understand the requirements of each question before you begin coding.
#
# 3. **Write Your Code in the Provided Cells**: For each question, a code cell is provided where you should write your solution. Do not modify any other cells or sections of the notebook.
#
# 4. **Execute Your Code**: After writing your code in each cell, run the cell to check if your code produces the expected results. Verify that the output matches the requirements specified in the question.
#
# 5. **Complete All Questions**: Ensure that you attempt and complete all the questions provided in the notebook. Each question is designed to test different Pandas skills and concepts.
#
# 6. **Review Your Work**: Before submitting, double-check your answers and make sure all questions are addressed. Ensure that the notebook runs without errors and that all outputs are correct.
#
# 7. **Download Your Notebook**: Once you have completed all the questions and verified your solutions, download the notebook file (.ipynb). You can do this by selecting `File` > `Download` > `Download .ipynb` from the Google Colab menu.
#
# 8. **Submit Your Practice**: Upload the downloaded .ipynb file to the designated learning platform for submission.
#
# 9. **Verify Submission**: Ensure that you have uploaded the correct file and that it is not corrupted. If you encounter any issues with the file, you may need to resubmit.
#
# ---
#
# Good luck with your Practice!

# %%
import numpy as np
import pandas as pd

locations_data_url = "https://s3.ap-south-1.amazonaws.com/new-assets.ccbp.in/frontend/content/aiml/classical-ml/locations_dataset.csv"
episodes_data_url = "https://s3.ap-south-1.amazonaws.com/new-assets.ccbp.in/frontend/content/aiml/classical-ml/episodes_dataset.csv"
character_data_url = "https://s3.ap-south-1.amazonaws.com/new-assets.ccbp.in/frontend/content/aiml/classical-ml/characters_dataset.csv"

characters = pd.read_csv(character_data_url,index_col=0)
episodes = pd.read_csv(episodes_data_url,index_col=0)
locations = pd.read_csv(locations_data_url,index_col=0)

# %% [markdown]
# Q1. You are given a DataFrame locations containing a column 'name' with the names of different locations, find only the location name with the maximum number of characters (longest name) and print it.

# %%
location_lengths = locations['name'].apply(len)
max_length = location_lengths.max()
longest_locations = locations[location_lengths == max_length]['name']
print(longest_locations.iloc[0])
# Out:
# Earth (Replacement Dimension)

# %% [markdown]
# Q2. From the characters DataFrame, count how many characters have a `status` of `unknown` and print the result as a frequency table, display the result as a Series.

# %%
# write your code here
status_distribution = characters[characters['status'] == 'unknown']['status'].value_counts()
print(status_distribution)
# Out:
# status
# unknown    6
# Name: count, dtype: int64

# %% [markdown]
# Q3. From the `episodes` DataFrame, find the episode with the earliest `created` date and print its name.

# %%
# write your code here
# episodes.columns
# episodes.head(5)
earliest_date = episodes['created'].min()
earliest_episode = episodes[episodes['created']==earliest_date]['name']
print(earliest_episode.iloc[0])
# Out:
# Pilot

# %% [markdown]
# Q4. From the `characters` DataFrame, count how many characters belong to each species, set the index name to `species` and the Series name to `count`, then print the result.

# %%
# write your code here
num_of_species_counts = characters.groupby('species')['name'].count()
num_of_species_counts
# Out:
# species
# Alien     5
# Human    15
# Name: name, dtype: int64

# %% [markdown]
# Q5. Group the episodes DataFrame by `air_date`, count how many episodes aired on each date, and then print the total number of air dates.

# %%
episodes_count = episodes.groupby('air_date')['name'].count()
print(len(episodes_count))
# Out:
# 20

# %% [markdown]
# Q.6 Using the `characters` DataFrame, group the data by `gender` and count how many characters belong to each gender based on id. Print the result.

# %%
# write your code here
characters_count = characters.groupby('gender')['id'].count()
print(characters_count)
# Out:
# gender
# Female      4
# Male       15
# unknown     1
# Name: id, dtype: int64

# %% [markdown]
# Q.7 Convert all episode names in the `episodes` DataFrame to uppercase and print the `name` column.

# %%
# write your code here
episodes = episodes.assign(name=episodes['name'].str.upper())
print(episodes['name'])
# Out:
# 0                                       PILOT
# 1                               LAWNMOWER DOG
# 2                                ANATOMY PARK
# 3                      M. NIGHT SHAYM-ALIENS!
# 4                        MEESEEKS AND DESTROY
# 5                              RICK POTION #9
# 6                         RAISING GAZORPAZORP
# 7                               RIXTY MINUTES
# 8             SOMETHING RICKED THIS WAY COMES
# 9        CLOSE RICK-COUNTERS OF THE RICK KIND
# 10                            RICKSY BUSINESS
# 11                           A RICKLE IN TIME
# 12                             MORTYNIGHT RUN
# 13                   AUTO EROTIC ASSIMILATION
# 14                              TOTAL RICKALL
# 15                               GET SCHWIFTY
# 16                    THE RICKS MUST BE CRAZY
# 17              BIG TROUBLE IN LITTLE SANCHEZ
# 18    INTERDIMENSIONAL CABLE 2: TEMPTING FATE
# 19                     LOOK WHO'S PURGING NOW
# Name: name, dtype: object

# %% [markdown]
# Q.8 From the `characters` DataFrame, select all characters whose species is **Human**. Then count how many characters have gender **Male**, set the index name to `gender` and the Series name to `count`, and print the result.

# %%
# write your code here
humans = characters[characters['species'] == 'Human']
male_characters = humans[humans['gender'] == 'Male']
gender = male_characters.groupby('gender')['name'].count()
print(gender)
# Out:
# gender
# Male    12
# Name: name, dtype: int64

# %% [markdown]
# Q.9 From the `characters` data, select all rows where the **name** contains the word **Citadel** (case-insensitive) and print the resulting DataFrame.

# %%
# write your code here
citadel_characters = characters[characters['name'].str.contains('Citadel', case=False)]
print(citadel_characters)
# Out:
# Empty DataFrame
# Columns: [id, name, status, species, type, gender, origin, location, image, episode, url, created]
# Index: []

# %% [markdown]
# Q.10 From the `episodes` DataFrame, extract the **names of all episodes aired in 2013** and print them as a Python list.

# %%
# write your code here
episodes_2013 = episodes[episodes['air_date'].str.contains('2013')]
episode_names = episodes_2013['name'].tolist()
print(episode_names)
# Out:
# ['PILOT', 'LAWNMOWER DOG', 'ANATOMY PARK']

# %% [markdown]
# Q.11 Find the three `characters` who appeared in the most episodes by applying len to the `episode` column, and print their episode counts.

# %%
# write your code here
character_episodes_count = characters.groupby('name')['episode'].apply(len)
top_three_characters = character_episodes_count.nlargest(3)
print(top_three_characters)
# Out:
# name
# Abadango Cluster Princess    1
# Abradolf Lincler             1
# Adjudicator Rick             1
# Name: episode, dtype: int64

# %% [markdown]
# Q.12 From the `characters` data, extract the **name** value from each **origin** dictionary, find how many unique origins there are, and print the count.

# %%
import ast

unique_characters = characters.assign(origin=characters['origin'].apply(lambda x: ast.literal_eval(x)['name']))
unique_origins = unique_characters['origin'].nunique()
print(unique_origins)
# Out:
# 4

# %% [markdown]
# Q. 13 Convert the **air_date** column of the episodes DataFrame to datetime, find the most recent episode (latest air date), and print its name.

# %%
# write your code here
episodes = episodes.assign(air_date=pd.to_datetime(episodes['air_date']))
most_recent_episode = episodes[episodes['air_date'] == episodes['air_date'].max()]
print(most_recent_episode)
# Out:
#     id                    name   air_date episode  \
# 19  20  LOOK WHO'S PURGING NOW 2015-09-27  S02E09
#
#                                            characters  \
# 19  ['https://rickandmortyapi.com/api/character/1'...
#
#                                            url                   created
# 19  https://rickandmortyapi.com/api/episode/20  2017-11-10T12:56:35.772Z

# %% [markdown]
# Q. 14 From the `characters` data, determine the **most common species** and print it.

# %%
# write your code here
most_common_species = characters['species'].value_counts().idxmax()
print(most_common_species)
# Out:
# Human

# %% [markdown]
# Q. 15 From the `characters` data, select and print all character names that **start with the letter "A"**.

# %%
# write your code here
name_count = characters[characters['name'].str.startswith('A')]
print(name_count)
# Out:
#     id                       name   status species  \
# 5    6  Abadango Cluster Princess    Alive   Alien
# 6    7           Abradolf Lincler  unknown   Human
# 7    8           Adjudicator Rick     Dead   Human
# 8    9            Agency Director     Dead   Human
# 9   10                 Alan Rails     Dead   Human
# 10  11            Albert Einstein     Dead   Human
# 11  12                  Alexander     Dead   Human
# 12  13               Alien Googah  unknown   Alien
# 13  14                Alien Morty  unknown   Alien
# 14  15                 Alien Rick  unknown   Alien
# 15  16               Amish Cyborg     Dead   Alien
# 16  17                      Annie    Alive   Human
# 17  18              Antenna Morty    Alive   Human
# 18  19               Antenna Rick  unknown   Human
# 19  20    Ants in my Eyes Johnson  unknown   Human
#
#                                   type   gender  \
# 5                                  NaN   Female
# 6                   Genetic experiment     Male
# 7                                  NaN     Male
# 8                                  NaN     Male
# 9   Superhuman (Ghost trains summoner)     Male
# 10                                 NaN     Male
# 11                                 NaN     Male
# 12                                 NaN  unknown
# 13                                 NaN     Male
# 14                                 NaN     Male
# 15                            Parasite     Male
# 16                                 NaN   Female
# 17                 Human with antennae     Male
# 18                 Human with antennae     Male
# 19         Human with ants in his eyes     Male
#
#                                                origin  \
# 5   {'name': 'Abadango', 'url': 'https://rickandmo...
# 6   {'name': 'Earth (Replacement Dimension)', 'url...
# 7                      {'name': 'unknown', 'url': ''}
# 8   {'name': 'Earth (Replacement Dimension)', 'url...
# 9                      {'name': 'unknown', 'url': ''}
# 10  {'name': 'Earth (C-137)', 'url': 'https://rick...
# 11  {'name': 'Earth (C-137)', 'url': 'https://rick...
# 12                     {'name': 'unknown', 'url': ''}
# 13                     {'name': 'unknown', 'url': ''}
# 14                     {'name': 'unknown', 'url': ''}
# 15                     {'name': 'unknown', 'url': ''}
# 16  {'name': 'Earth (C-137)', 'url': 'https://rick...
# 17                     {'name': 'unknown', 'url': ''}
# 18                     {'name': 'unknown', 'url': ''}
# 19                     {'name': 'unknown', 'url': ''}
#
#                                              location  \
# 5   {'name': 'Abadango', 'url': 'https://rickandmo...
# 6   {'name': 'Testicle Monster Dimension', 'url': ...
# 7   {'name': 'Citadel of Ricks', 'url': 'https://r...
# 8   {'name': 'Earth (Replacement Dimension)', 'url...
# 9   {'name': "Worldender's lair", 'url': 'https://...
# 10  {'name': 'Earth (Replacement Dimension)', 'url...
# 11  {'name': 'Anatomy Park', 'url': 'https://ricka...
# 12  {'name': 'Earth (Replacement Dimension)', 'url...
# 13  {'name': 'Citadel of Ricks', 'url': 'https://r...
# 14  {'name': 'Citadel of Ricks', 'url': 'https://r...
# 15  {'name': 'Earth (Replacement Dimension)', 'url...
# 16  {'name': 'Anatomy Park', 'url': 'https://ricka...
# 17  {'name': 'Citadel of Ricks', 'url': 'https://r...
# 18                     {'name': 'unknown', 'url': ''}
# 19  {'name': 'Interdimensional Cable', 'url': 'htt...
#
#                                                 image  \
# 5   https://rickandmortyapi.com/api/character/avat...
# 6   https://rickandmortyapi.com/api/character/avat...
# 7   https://rickandmortyapi.com/api/character/avat...
# 8   https://rickandmortyapi.com/api/character/avat...
# 9   https://rickandmortyapi.com/api/character/avat...
# 10  https://rickandmortyapi.com/api/character/avat...
# 11  https://rickandmortyapi.com/api/character/avat...
# 12  https://rickandmortyapi.com/api/character/avat...
# 13  https://rickandmortyapi.com/api/character/avat...
# 14  https://rickandmortyapi.com/api/character/avat...
# 15  https://rickandmortyapi.com/api/character/avat...
# 16  https://rickandmortyapi.com/api/character/avat...
# 17  https://rickandmortyapi.com/api/character/avat...
# 18  https://rickandmortyapi.com/api/character/avat...
# 19  https://rickandmortyapi.com/api/character/avat...
#
#                                               episode  \
# 5      ['https://rickandmortyapi.com/api/episode/27']
# 6   ['https://rickandmortyapi.com/api/episode/10',...
# 7      ['https://rickandmortyapi.com/api/episode/28']
# 8      ['https://rickandmortyapi.com/api/episode/24']
# 9      ['https://rickandmortyapi.com/api/episode/25']
# 10     ['https://rickandmortyapi.com/api/episode/12']
# 11      ['https://rickandmortyapi.com/api/episode/3']
# 12     ['https://rickandmortyapi.com/api/episode/31']
# 13     ['https://rickandmortyapi.com/api/episode/10']
# 14     ['https://rickandmortyapi.com/api/episode/10']
# 15     ['https://rickandmortyapi.com/api/episode/15']
# 16      ['https://rickandmortyapi.com/api/episode/3']
# 17  ['https://rickandmortyapi.com/api/episode/10',...
# 18     ['https://rickandmortyapi.com/api/episode/10']
# 19      ['https://rickandmortyapi.com/api/episode/8']
#
#                                              url                   created
# 5    https://rickandmortyapi.com/api/character/6  2017-11-04T19:50:28.250Z
# 6    https://rickandmortyapi.com/api/character/7  2017-11-04T19:59:20.523Z
# 7    https://rickandmortyapi.com/api/character/8  2017-11-04T20:03:34.737Z
# 8    https://rickandmortyapi.com/api/character/9  2017-11-04T20:06:54.976Z
# 9   https://rickandmortyapi.com/api/character/10  2017-11-04T20:19:09.017Z
# 10  https://rickandmortyapi.com/api/character/11  2017-11-04T20:20:20.965Z
# 11  https://rickandmortyapi.com/api/character/12  2017-11-04T20:32:33.144Z
# 12  https://rickandmortyapi.com/api/character/13  2017-11-04T20:33:30.779Z
# 13  https://rickandmortyapi.com/api/character/14  2017-11-04T20:51:31.373Z
# 14  https://rickandmortyapi.com/api/character/15  2017-11-04T20:56:13.215Z
# 15  https://rickandmortyapi.com/api/character/16  2017-11-04T21:12:45.235Z
# 16  https://rickandmortyapi.com/api/character/17  2017-11-04T22:21:24.481Z
# 17  https://rickandmortyapi.com/api/character/18  2017-11-04T22:25:29.008Z
# 18  https://rickandmortyapi.com/api/character/19  2017-11-04T22:28:13.756Z
# 19  https://rickandmortyapi.com/api/character/20  2017-11-04T22:34:53.659Z

# %% [markdown]
# # End!
